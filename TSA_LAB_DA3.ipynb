# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : Moving Average</h3>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div><h4>
# Exercise No. 1</h4> <div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : 23MDT0047 </div>
# Date : April 23, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To find moving average values  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Passengers Data from January, 1949 (01-1949) to December, 1960 (12-1960).&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbspIt consists of two columns - Month and Passengers&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from numpy import log

# %%
df = pd.read_excel("Passenger.xlsx")
df
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
n = int(input('Enter the number of years for Moving Average:'))
df['MA']=df['Passengers'].rolling(window = n).mean()
print((df['MA']).head(30))
# Out:
# Enter the number of years for Moving Average:7
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6     127.857143
# 7     133.000000
# 8     135.571429
# 9     133.714286
# 10    130.142857
# 11    129.714286
# 12    126.857143
# 13    123.714286
# 14    122.714286
# 15    122.571429
# 16    123.428571
# 17    129.857143
# 18    137.285714
# 19    145.142857
# 20    149.714286
# 21    148.571429
# 22    145.571429
# 23    147.714286
# 24    147.142857
# 25    144.285714
# 26    145.428571
# 27    146.142857
# 28    151.714286
# 29    160.857143
# Name: MA, dtype: float64

# %%
df['Passengers'].plot(color='green',linewidth =3,figsize=(12,6),label = 'Actual data')
df['MA'].plot(color='red',linewidth =3,figsize=(12,6),label = 'MA Values')
plt.legend()
plt.title('Passenger Value MA for 7 years')
plt.show()

# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : Moving Average</h3>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <h4>Exercise No. 2 </h4><div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : 23MDT0047 </div>
# Date : April 23, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To find moving average values  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Electric Production from 01/01/1985 to 01/01/2018.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;It consists of two columns - Date and Value&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %%
df2 = pd.read_excel("ELECTRIC_PRODUCTION.xlsx")
df2
# Out:
#           DATE     Value
# 0   1985-01-01   72.5052
# 1   1985-01-02   70.6720
# 2   1985-01-03   62.4502
# 3   1985-01-04   57.4714
# 4   1985-01-05   55.3151
# ..         ...       ...
# 392 2017-01-09   98.6154
# 393 2017-01-10   93.6137
# 394 2017-01-11   97.3359
# 395 2017-01-12  114.7212
# 396 2018-01-01  129.4048
#
# [397 rows x 2 columns]

# %%
n = int(input('Enter the number of years for Moving Average:'))
df2['MA']=df2['Value'].rolling(window = n).mean()
print((df2['MA']).head(30))
# Out:
# Enter the number of years for Moving Average:9
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8     62.550844
# 9     60.751978
# 10    59.344033
# 11    60.040067
# 12    61.799433
# 13    63.207411
# 14    63.666489
# 15    63.045678
# 16    62.219589
# 17    62.143578
# 18    63.193589
# 19    63.913711
# 20    63.056600
# 21    61.303989
# 22    60.343411
# 23    61.000444
# 24    62.865144
# 25    64.448289
# 26    65.082678
# 27    64.459689
# 28    63.836556
# 29    64.157811
# Name: MA, dtype: float64

# %%
df2['Value'].plot(color='green',linewidth =3,figsize=(12,6),label = 'Actual data')
df2['MA'].plot(color='red',linewidth =3,figsize=(12,6),label = 'MA Values')
plt.legend()
plt.title('Electric Production Value MA for 9 years')
plt.show()

# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : Moving Average</h3>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <h4>Exercise No. 3</h4> <div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : 23MDT0047 </div>
# Date : April 23, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To find moving average values  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Stock Price Data from 01/04/2015 to 31/03/2021.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;It consists of six columns - Date,Open,High,Low,Close,Volume  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;It&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %%
df3 = pd.read_excel("Stock_Market_data.xlsx")
df3
# Out:
#                      Date    Open    High     Low   Close    Volume
# 0     2015-01-04 16:00:00   40.60   40.76   40.31   40.72  36865322
# 1     2015-02-04 16:00:00   40.66   40.74   40.12   40.29  37487476
# 2     2015-06-04 16:00:00   40.34   41.78   40.18   41.55  39223692
# 3     2015-07-04 16:00:00   41.61   41.91   41.31   41.53  28809375
# 4     2015-08-04 16:00:00   41.48   41.69   41.04   41.42  24753438
# ...                   ...     ...     ...     ...     ...       ...
# 1506   3/25/2021 16:00:00  235.30  236.94  231.57  232.34  34061853
# 1507   3/26/2021 16:00:00  231.55  236.71  231.55  236.48  25479853
# 1508   3/29/2021 16:00:00  236.59  236.80  231.88  235.24  25227455
# 1509   3/30/2021 16:00:00  233.53  233.85  231.10  231.85  24792012
# 1510   3/31/2021 16:00:00  232.91  239.10  232.39  235.77  43623471
#
# [1511 rows x 6 columns]

# %%
n = int(input('Enter the number of years for Moving Average:'))
df3['MA']=df3['Close'].rolling(window = n).mean()
print((df3['MA']).head(30))
# Out:
# Enter the number of years for Moving Average:11
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10    41.503636
# 11    41.585455
# 12    41.823636
# 13    41.922727
# 14    42.055455
# 15    42.230000
# 16    42.810909
# 17    43.384545
# 18    44.057273
# 19    44.730909
# 20    45.310909
# 21    45.901818
# 22    46.503636
# 23    46.930000
# 24    47.260909
# 25    47.598182
# 26    47.999091
# 27    47.953636
# 28    47.891818
# 29    47.752727
# Name: MA, dtype: float64

# %%
df3['Close'].plot(color='green',linewidth =3,figsize=(12,6),label = 'Actual data')
df3['MA'].plot(color='red',linewidth =3,figsize=(12,6),label = 'MA Values')
plt.legend()
plt.title('Stock Price closing value MA for 11 years')
plt.show()

# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : ACF and PACF Values</h3>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div><h4>
# Exercise No. 4</h4> <div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : 23MDT0047 </div>
# Date : April 23, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To find moving average values  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Passengers Data from January, 1949 (01-1949) to December, 1960 (12-1960).&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbspIt consists of two columns - Month and Passengers&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %%
df['Passengers_log'] = np.log(df['Passengers'])
df['Passengers_log_diff2'] = df['Passengers_log']-df['Passengers_log'].shift(2)
result = adfuller(df['Passengers_log_diff2'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -3.167907
# p-value: 0.021919

# %% [markdown]
# Hence, our data has been transformed into stationary data.

# %%
from statsmodels.tsa.stattools import adfuller,acf,pacf
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf_val = acf(df['Passengers_log_diff2'].dropna())

# %%
acf_val
# Out:
# array([ 1.        ,  0.53501222, -0.0738737 , -0.30248819, -0.36210495,
#        -0.19849439, -0.06691657, -0.22467414, -0.375865  , -0.28325205,
#        -0.05289305,  0.47847371,  0.87571977,  0.47158073, -0.06937612,
#        -0.26205318, -0.29941854, -0.16132614, -0.06620661, -0.23406575,
#        -0.37188302, -0.26125746])

# %%
plot_acf(df['Passengers_log_diff2'].dropna(),lags=40)

# %%
plot_pacf(df['Passengers_log_diff2'].dropna(),lags=40)

# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : ACF and PACF Values</h3>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <h4>Exercise No. 5 </h4><div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : 23MDT0047 </div>
# Date : April 23, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To find moving average values  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Electric Production from 01/01/1985 to 01/01/2018.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;It consists of two columns - Date and Value&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %%
df2['Value_log'] = np.log(df2['Value'])
df2['Value_log_diff'] = df2['Value_log']-df2['Value_log'].shift(1)
result = adfuller(df2['Value_log_diff'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -6.748333
# p-value: 0.000000

# %% [markdown]
# Hence, our data has been transformed into stationary data.

# %%
acf_val = acf(df2['Value_log_diff'].dropna())

# %%
acf_val
# Out:
# array([ 1.        ,  0.38445032, -0.43294285, -0.79175348, -0.40991521,
#         0.38449087,  0.76926709,  0.38539589, -0.41066568, -0.79114935,
#        -0.40659745,  0.39691407,  0.88626219,  0.37705106, -0.40680457,
#        -0.78666236, -0.38789489,  0.3860148 ,  0.74393216,  0.37591781,
#        -0.39077284, -0.7712331 , -0.39032233,  0.38837189,  0.83967565,
#         0.36567819])

# %%
plot_acf(df2['Value_log_diff'].dropna(),lags=40)

# %%
plot_pacf(df2['Value_log_diff'].dropna(),lags=40)

# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : ACF and PACF Values</h3>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <h4>Exercise No. 6</h4> <div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : 23MDT0047 </div>
# Date : April 23, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To find moving average values  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Stock Price Data from 01/04/2015 to 31/03/2021.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;It consists of six columns - Date,Open,High,Low,Close,Volume  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %%
df3['Close_log'] = np.log(df3['Close'])
df3['Close_log_diff'] = df3['Close_log']-df3['Close_log'].shift(1)
result = adfuller(df3['Close_log_diff'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -13.801078
# p-value: 0.000000

# %% [markdown]
# Hence, our data has been transformed into stationary data.

# %%
acf_val = acf(df3['Close_log_diff'].dropna())

# %%
acf_val
# Out:
# array([ 1.        , -0.22485709,  0.03986658,  0.02479212, -0.04145564,
#        -0.00591859, -0.0857226 ,  0.12274216, -0.1567617 ,  0.11398003,
#        -0.05525134,  0.00772274,  0.02492434, -0.05857112,  0.05899672,
#        -0.08887802,  0.08074447, -0.02497748,  0.02458677, -0.0222671 ,
#        -0.03535926,  0.04872817, -0.06999959,  0.02823669, -0.06054893,
#         0.008926  , -0.04489027,  0.01665361, -0.01031956, -0.01387659,
#         0.03690032, -0.05713312])

# %%
plot_acf(df3['Close_log_diff'].dropna(),lags=40)

# %%
plot_pacf(df3['Close_log_diff'].dropna(),lags=40)
