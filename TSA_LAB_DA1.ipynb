# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : STATIONARITY ANALYSIS</h3> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %% [markdown]
# <h4>Exercise No. 1</h4> <div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : <u>23MDT0047 </u></div>
# Date : April 19, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To check whether data is stationary or not. &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Passengers Data from January, 1949 (01-1949) to December, 1960 (12-1960).&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Data contains two variable, they are: Month and Passengers.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %% [markdown]
# - Null Hypothesis : Data is non-stationary
# - Alternate Hypothesis : Data is stationary

# %% [markdown]
# **Input and Output**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
df = pd.read_excel("Passenger.xlsx")
df.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
plt.plot(df['Passengers'],color = "red")
plt.show()

# %%
plt.hist(df['Passengers'],edgecolor = 'black')
plt.show()

# %%
# Perform Augmented - Dickey Fuller Test
ad = df["Passengers"].values
result = adfuller(ad)
print(f"ADF-statistic: {result[0]:.5f}")
print(f"p-value: {result[1]:.5f}")
# Out:
# ADF-statistic: 0.81537
# p-value: 0.99188

# %% [markdown]
# ### Conclusion:

# %%
if result[1]> 0.05:
    print("Since p-value > 0.05, we accept null hypothesis \n Given data is not stationary")
else:
    print("Since p-value < 0.05, we reject null hypothesis \n Given data is stationary")
# Out:
# Since p-value > 0.05, we accept null hypothesis
#  Given data is not stationary

# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : STATIONARITY ANALYSIS</h3> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %% [markdown]
# <h4>Exercise No. 2</h4> <div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No :<u> 23MDT0047</u></div>
# Date : April 19, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To check whether data is stationary or not. &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Microsoft stock price data from 01/04/2015 to 31/03/2021.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Data contains 5 variables, they are: Date, Open, High, Low, Close and Volume&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %% [markdown]
# - Null Hypothesis H0: The given Microsoft stock price data is stationary.
# - Alternative H1: The given Microsoft stock price data is not stationary.

# %% [markdown]
# **Input and Output**

# %%
data = pd.read_excel("Stock_Market_data.xlsx")
data.head()
# Out:
#                   Date   Open   High    Low  Close    Volume
# 0  2015-01-04 16:00:00  40.60  40.76  40.31  40.72  36865322
# 1  2015-02-04 16:00:00  40.66  40.74  40.12  40.29  37487476
# 2  2015-06-04 16:00:00  40.34  41.78  40.18  41.55  39223692
# 3  2015-07-04 16:00:00  41.61  41.91  41.31  41.53  28809375
# 4  2015-08-04 16:00:00  41.48  41.69  41.04  41.42  24753438

# %% [markdown]
# ### For "open"

# %%
plt.plot(data['Open'],color = "red")
plt.show()

# %%
# Perform Augmented - Dickey Fuller Test
ad = data["Open"].values
result = adfuller(ad)
print(f"ADF-statistic: {result[0]:.5f}")
print(f"p-value: {result[1]:.5f}")
# Out:
# ADF-statistic: 0.82392
# p-value: 0.99201

# %% [markdown]
# ### Conclusion

# %%
if result[1]> 0.05:
    print("Since p-value > 0.05, we accept null hypothesis \n Given data is not stationary")
else:
    print("Since p-value < 0.05, we reject null hypothesis \n Given data is stationary")
# Out:
# Since p-value > 0.05, we accept null hypothesis
#  Given data is not stationary

# %% [markdown]
# ### For "High"

# %%
plt.plot(data['High'],color = "purple")
plt.show()

# %%
# Perform Augmented - Dickey Fuller Test
ad = data["High"].values
result = adfuller(ad)
print(f"ADF-statistic: {result[0]:.5f}")
print(f"p - value: {result[1]:.5f}")
# Out:
# ADF-statistic: 1.57042
# p - value: 0.99777

# %%
if result[1]> 0.05:
    print("Since p-value > 0.05, we accept null hypothesis \n Given data is not stationary")
else:
    print("Since p-value < 0.05, we reject null hypothesis \n Given data is stationary")
# Out:
# Since p-value > 0.05, we accept null hypothesis
#  Given data is not stationary

# %% [markdown]
# ### For "Low"

# %%
plt.plot(data['Low'],color = "green")
plt.show()

# %%
# Perform Augmented - Dickey Fuller Test
ad = data["Low"].values
result = adfuller(ad)
print(f"ADF-statistic: {result[0]:.5f}")
print(f"p-value: {result[1]:.5f}")
# Out:
# ADF-statistic: 1.22483
# p-value: 0.99615

# %%
if result[1]> 0.05:
    print("Since p-value > 0.05, we accept null hypothesis \n Given data is not stationary")
else:
    print("Since p-value < 0.05, we reject null hypothesis \n Given data is stationary")
# Out:
# Since p-value > 0.05, we accept null hypothesis
#  Given data is not stationary

# %% [markdown]
# ### For "Close"

# %%
plt.plot(data['Close'],color = "blue")
plt.show()

# %%
# Perform Augmented - Dickey Fuller Test
ad = data["Close"].values
result = adfuller(ad)
print(f"ADF-statistic: {result[0]:.5f}")
print(f"p-value: {result[1]:.5f}")
# Out:
# ADF-statistic: 1.73714
# p-value: 0.99822

# %%
if result[1]> 0.05:
    print("Since p-value > 0.05, we accept null hypothesis \n Given data is not stationary")
else:
    print("Since p-value < 0.05, we reject null hypothesis \n Given data is stationary")
# Out:
# Since p-value > 0.05, we accept null hypothesis
#  Given data is not stationary

# %% [markdown]
# **Conclusion**:
# <br>The given Microsoft stock price data is not stationary

# %% [markdown]
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<h3>TITLE : STATIONARITY ANALYSIS</h3> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %% [markdown]
# <h4>Exercise No. 3</h4> <div style="text-align:Right">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Reg No : <u>23MDT0047</u> </div>
# Date : April 19, 2024
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>AIM :</b> To check whether data is stationary or not. &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>Data Description :</b> Electric Productionfrom 01/01/1985 to 01/01/2018.&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>
# <div style="text-align:center">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Data contains 2 variables, they are: Date and Value
# .&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</div>

# %% [markdown]
# - Null Hypothesis H0: The given Electric Production data is stationary.
# - Alternative H1: The given Electric Production data is not stationary.

# %% [markdown]
# **Input and Output**

# %%
data = pd.read_excel("ELECTRIC_PRODUCTION.xlsx")
data.head()
# Out:
#         DATE    Value
# 0 1985-01-01  72.5052
# 1 1985-01-02  70.6720
# 2 1985-01-03  62.4502
# 3 1985-01-04  57.4714
# 4 1985-01-05  55.3151

# %%
plt.plot(data['Value'],color = "blue")
plt.show()

# %%
# Perform Augmented - Dickey Fuller Test
ad = data["Value"].values
result = adfuller(ad)
print(f"ADF-statistic: {result[0]:.5f}")
print(f"p-value: {result[1]:.5f}")
# Out:
# ADF-statistic: -2.25699
# p-value: 0.18621

# %% [markdown]
# ### Conclusion

# %%
if result[1]> 0.05:
    print("Since p-value > 0.05, we accept null hypothesis \n Given data is not stationary")
else:
    print("Since p-value < 0.05, we reject null hypothesis \n Given data is stationary")
# Out:
# Since p-value > 0.05, we accept null hypothesis
#  Given data is not stationary
