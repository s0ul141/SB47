# %%
import pandas as pd
import numpy as np

# %%
#Question 1
df1 = pd.DataFrame(np.random.randn(10,5),\
                   columns=['col1','col2','col3','col4','col5'], index= ["row"+str(i+1) for i in range(0,10)])
df1

# %%
df1.describe()
# Out:
#             col1       col2       col3       col4       col5
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.608332  -0.080023  -0.048562   0.716213   0.086714
# std     1.158796   0.862123   0.954365   0.945002   1.181111
# min    -1.491258  -1.347759  -1.270485  -1.315907  -1.173123
# 25%    -0.018120  -0.793405  -0.729174   0.450525  -0.679887
# 50%     0.739445   0.012886  -0.181654   0.653663  -0.364794
# 75%     1.636789   0.567255   0.265347   1.237139   0.793520
# max     1.943621   0.947252   1.849264   1.922942   2.383145

# %%
df1.shape
# Out:
# (10, 5)

# %%
df1.size
# Out:
# 50

# %%
print("mean-")
print(df1.mean())
print("\nsum-")
print(df1.sum())
print("cumsum")
print(df1.cumsum())
# Out:
# mean-
# col1    0.608332
# col2   -0.080023
# col3   -0.048562
# col4    0.716213
# col5    0.086714
# dtype: float64
#
# sum-
# col1    6.083317
# col2   -0.800226
# col3   -0.485615
# col4    7.162125
# col5    0.867141
# dtype: float64
# cumsum
#            col1      col2      col3      col4      col5
# row1   1.883151 -1.347759 -1.270485  0.969397 -1.173123
# row2   3.826772 -1.761378 -2.017940  2.892339  0.307391
# row3   5.694331 -0.855333 -2.879165  4.802404  0.039388
# row4   6.496787  0.091919 -3.034176  5.416483  0.961595
# row5   6.873213 -1.007482 -2.735937  6.742869  0.267027
# row6   6.723578 -1.442636 -0.886674  7.415164  0.674489
# row7   5.953662 -0.903387 -1.561006  7.446994  0.038643
# row8   6.630095 -0.326796 -1.769305  7.843001 -1.054419
# row9   5.138838  0.112596 -1.602632  8.478032  1.328726
# row10  6.083317 -0.800226 -0.485615  7.162125  0.867141

# %%
#question 4
df2 = pd.DataFrame(np.random.randint(10,50,(5,5)),\
                   columns=['col1','col2','col3','col4','col5'], index= ["row"+str(i) for i in range(0,5)])
df2
# Out:
#       col1  col2  col3  col4  col5
# row0    24    32    38    30    28
# row1    14    32    45    29    17
# row2    18    23    15    10    18
# row3    25    25    21    14    49
# row4    38    36    20    37    45

# %%
df2.describe()
# Out:
#             col1       col2       col3       col4       col5
# count   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   28.800000  29.600000  31.200000  27.000000  30.600000
# std    10.401923  11.148991  13.553597   6.123724  15.741664
# min    17.000000  10.000000  13.000000  18.000000  10.000000
# 25%    21.000000  33.000000  23.000000  26.000000  18.000000
# 50%    27.000000  33.000000  32.000000  27.000000  37.000000
# 75%    39.000000  34.000000  42.000000  29.000000  42.000000
# max    40.000000  38.000000  46.000000  35.000000  46.000000

# %%
#Q5
df3= df2.append(df1)
df3
# Out:
#             col1       col2       col3       col4       col5
# row0   24.000000  32.000000  38.000000  30.000000  28.000000
# row1   14.000000  32.000000  45.000000  29.000000  17.000000
# row2   18.000000  23.000000  15.000000  10.000000  18.000000
# row3   25.000000  25.000000  21.000000  14.000000  49.000000
# row4   38.000000  36.000000  20.000000  37.000000  45.000000
# row1    1.883151  -1.347759  -1.270485   0.969397  -1.173123
# row2    1.943621  -0.413619  -0.747455   1.922942   1.480515
# row3    1.867559   0.906045  -0.861226   1.910065  -0.268003
# row4    0.802456   0.947252  -0.155010   0.614079   0.922207
# row5    0.376426  -1.099401   0.298238   1.326386  -0.694568
# row6   -0.149635  -0.435154   1.849264   0.672295   0.407462
# row7   -0.769916   0.539249  -0.674333   0.031831  -0.635846
# row8    0.676433   0.576591  -0.208299   0.396007  -1.093062
# row9   -1.491258   0.439392   0.166673   0.635031   2.383145
# ...

# %%
#q6
#i
df3_i = df3.drop(["row0", "row8"])
df3_i
# Out:
#             col1       col2       col3       col4       col5
# row1   14.000000  32.000000  45.000000  29.000000  17.000000
# row2   18.000000  23.000000  15.000000  10.000000  18.000000
# row3   25.000000  25.000000  21.000000  14.000000  49.000000
# row4   38.000000  36.000000  20.000000  37.000000  45.000000
# row1    1.883151  -1.347759  -1.270485   0.969397  -1.173123
# row2    1.943621  -0.413619  -0.747455   1.922942   1.480515
# row3    1.867559   0.906045  -0.861226   1.910065  -0.268003
# row4    0.802456   0.947252  -0.155010   0.614079   0.922207
# row5    0.376426  -1.099401   0.298238   1.326386  -0.694568
# row6   -0.149635  -0.435154   1.849264   0.672295   0.407462
# row7   -0.769916   0.539249  -0.674333   0.031831  -0.635846
# row9   -1.491258   0.439392   0.166673   0.635031   2.383145
# row10   0.944479  -0.912822   1.117016  -1.315907  -0.461585

# %%
#ii
df3_ii = df3.drop(columns=['col3'])
df3_ii
# Out:
#             col1       col2       col4       col5
# row1   14.000000  32.000000  29.000000  17.000000
# row2   18.000000  23.000000  10.000000  18.000000
# row3   25.000000  25.000000  14.000000  49.000000
# row4   38.000000  36.000000  37.000000  45.000000
# row1    1.883151  -1.347759   0.969397  -1.173123
# row2    1.943621  -0.413619   1.922942   1.480515
# row3    1.867559   0.906045   1.910065  -0.268003
# row4    0.802456   0.947252   0.614079   0.922207
# row5    0.376426  -1.099401   1.326386  -0.694568
# row6   -0.149635  -0.435154   0.672295   0.407462
# row7   -0.769916   0.539249   0.031831  -0.635846
# row9   -1.491258   0.439392   0.635031   2.383145
# row10   0.944479  -0.912822  -1.315907  -0.461585

# %%
#q6
df3['col6']=3*np.sqrt(abs(df3['col3']))+(df3['col5']**2)+10
df3
# Out:
# C:\Users\234DF8~1\AppData\Local\Temp/ipykernel_2520/636961132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['col6']=3*np.sqrt(abs(df3['col3']))+(df3['col5']**2)+10
#             col1       col2       col3       col4       col5         col6
# row1   14.000000  32.000000  45.000000  29.000000  17.000000   319.124612
# row2   18.000000  23.000000  15.000000  10.000000  18.000000   345.618950
# row3   25.000000  25.000000  21.000000  14.000000  49.000000  2424.747727
# row4   38.000000  36.000000  20.000000  37.000000  45.000000  2048.416408
# row1    1.883151  -1.347759  -1.270485   0.969397  -1.173123    14.757692
# row2    1.943621  -0.413619  -0.747455   1.922942   1.480515    14.785588
# ...

# %%
#q8
df3.to_csv("data.csv")

# %%
#q9
df4=df3
df4['col7']= np.abs(df3.min(axis=1)-df3.max(axis=1))
df4
# Out:
# C:\Users\234DF8~1\AppData\Local\Temp/ipykernel_2520/4001585467.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['col7']= np.abs(df3.min(axis=1)-df3.max(axis=1))
#             col1       col2       col3       col4       col5         col6  \
# row1   14.000000  32.000000  45.000000  29.000000  17.000000   319.124612
# row2   18.000000  23.000000  15.000000  10.000000  18.000000   345.618950
# row3   25.000000  25.000000  21.000000  14.000000  49.000000  2424.747727
# row4   38.000000  36.000000  20.000000  37.000000  45.000000  2048.416408
# row1    1.883151  -1.347759  -1.270485   0.969397  -1.173123    14.757692
# row2    1.943621  -0.413619  -0.747455   1.922942   1.480515    14.785588
# ...

# %%
df4['col8'] = df4['col7']*2
df4
# Out:
# C:\Users\234DF8~1\AppData\Local\Temp/ipykernel_2520/3123573526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['col8'] = df4['col7']*2
#             col1       col2       col3       col4       col5         col6  \
# row1   14.000000  32.000000  45.000000  29.000000  17.000000   319.124612
# row2   18.000000  23.000000  15.000000  10.000000  18.000000   345.618950
# row3   25.000000  25.000000  21.000000  14.000000  49.000000  2424.747727
# row4   38.000000  36.000000  20.000000  37.000000  45.000000  2048.416408
# row1    1.883151  -1.347759  -1.270485   0.969397  -1.173123    14.757692
# row2    1.943621  -0.413619  -0.747455   1.922942   1.480515    14.785588
# ...

# %%
#q10
df4.loc['ROW']= df4.mean()
df4= np.abs(df4)
df4
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1797: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
#             col1       col2       col3       col4       col5         col6  \
# row1   14.000000  32.000000  45.000000  29.000000  17.000000   319.124612
# row2   18.000000  23.000000  15.000000  10.000000  18.000000   345.618950
# row3   25.000000  25.000000  21.000000  14.000000  49.000000  2424.747727
# row4   38.000000  36.000000  20.000000  37.000000  45.000000  2048.416408
# row1    1.883151   1.347759   1.270485   0.969397   1.173123    14.757692
# row2    1.943621   0.413619   0.747455   1.922942   1.480515    14.785588
# ...

# %%
#q11
df4.to_excel('myData.xlsx',index=False)

# %%
#q12
data = pd.read_excel('myData.xlsx')
print(data.index)
data.plot(figsize=(16,9))
# Out:
# RangeIndex(start=0, stop=14, step=1)
# <AxesSubplot:>

# %%
data.plot(subplots=True, kind='area',figsize=(6,18))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
data['col7'].plot(kind='bar', figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='scatter',x='col3',y='col6')
# Out:
# <AxesSubplot:xlabel='col3', ylabel='col6'>

# %%
data['col2'].plot(kind="box", figsize=(16,9))
# Out:
# <AxesSubplot:>

# %%
data.loc[1].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  14 non-null     object
#  1   col1        14 non-null     float64
#  2   col2        14 non-null     float64
#  3   col3        14 non-null     float64
#  4   col4        14 non-null     float64
#  5   col5        14 non-null     float64
#  6   col6        14 non-null     float64
#  7   col7        14 non-null     float64
#  8   col8        14 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 1.1+ KB
