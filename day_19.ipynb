# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_excel('WQ.xlsx', sheet_name='June 04')

# %%
d1
# Out:
#     St. No  Depth   S.D   W.T  Salinity  Turbidity     DO    pH     TSM  \
# 0        1   0.65  0.25  32.4      18.6      14.40   6.50  8.00   85.08
# 1        2   2.25  0.25  29.5      19.1      58.70   7.10  8.08   69.88
# 2        3   2.75  0.25  29.4      20.3      24.40   7.80  8.10   54.12
# 3        4   2.25  0.75  29.2      20.1       4.03   7.40  8.03   21.88
# 4        5   1.75  1.00  29.3      19.2       8.39   7.60  8.15   33.04
# 5        6   3.00  0.75  29.0      23.0      12.70   6.30  8.05   51.92
# 6        7   2.75  0.75  28.9      21.7      19.50  11.20  8.06   62.80
# 7        8   0.75  0.75  29.3      20.9       4.40  11.80  8.36   40.40
# 8        9    NaN   NaN   NaN       NaN        NaN    NaN   NaN     NaN
# 9       10   3.00  1.75  29.0      25.3      16.40   9.92  8.02   52.80
# 10      11   0.25  0.15  29.9      20.1      34.10  11.70  8.20  167.20
# 11      12   2.50  1.00  28.6      24.0       8.36   6.90  8.01   42.16
# ...

# %%
xl = pd.ExcelFile('WQ.xlsx')

# %%
names = xl.sheet_names
print(names)
# Out:
# ['May 04', 'June 04', 'July 04', 'Aug 04', 'Sep 04', 'Oct 04', 'Nov 04', 'Dec 04', 'Jan 05', 'Feb 05', 'Mar 05', 'Apr 05', 'May 05', 'June 05', 'July 05', 'Aug 05', 'Sep 05', 'Oct 05', 'Nov 05', 'Dec 05', 'Jan 06', 'Feb 06', 'Mar 06', 'Apr 06', 'May 06', 'June 06', 'July 06', 'Aug 06', 'Sep 06']

# %%
# reading all excel sheets in the file all at once
xl = pd.ExcelFile('WQ.xlsx')
names = xl.sheet_names
df= pd.DataFrame() #blank dataframe
for sheet in names:
    temp= pd.read_excel("WQ.xlsx", sheet_name=sheet)
    df=pd.concat([df,temp])
df
# Out:
#     St. No  Depth  S.D   W.T  Salinity  Turbidity    DO    pH    TSM  \
# 0        1   1.00  1.0  29.5     10.00       5.21  8.37  9.05   18.0
# 1        2   2.25  0.5  30.0     10.40      16.00  6.90  8.27   23.2
# 2        3   2.50  0.5  29.6     11.80      13.70  6.79  8.27   26.8
# 3        4   1.85  NaN  29.6     10.70       3.72  5.17  8.64   22.6
# 4        5   1.50  1.5  29.3     11.70       4.22  6.46  8.70   18.0
# ..     ...    ...  ...   ...       ...        ...   ...   ...    ...
# 31      32   1.50  0.0  29.5      0.16      45.40  6.97  7.27   53.0
# 32      33   2.50  0.0  29.0      0.13     150.00  6.82  7.61  212.0
# 33      34   1.75  0.0  31.5      0.20     332.00  6.20  8.01  243.0
# 34      35   1.50  0.0  31.0      1.54     170.00  6.35  8.07   98.0
# 35      36   3.50  0.5  31.5      1.66     252.00  6.28  8.12  323.0
#
#        NH4-N    NO2-N     NO3-N    PO4-P   SiO2-Si        TN        TP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   St. No     1044 non-null   int64
#  1   Depth      1034 non-null   float64
#  2   S.D        1033 non-null   float64
#  3   W.T        1035 non-null   float64
#  4   Salinity   1035 non-null   float64
#  5   Turbidity  1030 non-null   float64
#  6   DO         1035 non-null   float64
#  7   pH         1036 non-null   float64
#  8   TSM        1026 non-null   float64
#  9   NH4-N      1026 non-null   float64
#  10  NO2-N      1036 non-null   float64
#  11  NO3-N      1031 non-null   float64
#  12  PO4-P      1035 non-null   float64
#  13  SiO2-Si    1033 non-null   float64
#  14  TN         1027 non-null   float64
#  15  TP         1012 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 138.7 KB

# %%
Data = pd.read_excel('WQ.xlsx')

# %%
df.describe()#stats
# Out:
#             St. No        Depth          S.D          W.T     Salinity  \
# count  1044.000000  1034.000000  1033.000000  1035.000000  1035.000000
# mean     18.500000     1.742621     0.576462    29.256531    12.163740
# std      10.393274     0.792122     0.532560     2.734294     9.174874
# min       1.000000     0.100000     0.000000    20.100000     0.000000
# 25%       9.750000     1.250000     0.150000    27.850000     4.405000
# 50%      18.500000     1.750000     0.500000    29.500000    11.130000
# 75%      27.250000     2.250000     1.000000    31.300000    19.100000
# max      36.000000     4.500000     3.750000    37.800000    35.300000
#
#          Turbidity           DO           pH          TSM        NH4-N  \
# count  1030.000000  1035.000000  1036.000000  1026.000000  1026.000000
# mean     54.999029     7.159511     8.304210    75.191285     2.960870
# std     113.721950     1.700331     0.417211   148.795049     2.705394
# ...

# %%
df.plot(kind='scatter',x='W.T', y='DO', figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='W.T', ylabel='DO'>

# %%
from scipy.stats import norm, describe
data=[1,-1,0,1,4,3,-2,6]
datacdf = norm.pdf(data,loc=0, scale=2)
print(datacdf)
describe(datacdf)
# Out:
# [0.17603266 0.17603266 0.19947114 0.17603266 0.02699548 0.0647588
#  0.12098536 0.00221592]
# DescribeResult(nobs=8, minmax=(0.0022159242059690038, 0.19947114020071635), mean=0.11781558723778078, variance=0.005895993849991474, skewness=-0.4408452406604044, kurtosis=-1.4339135511377334)

# %%
sum([0.17603266, 0.17603266, 0.19947114, 0.17603266, 0.02699548, 0.0647588,
 0.12098536, 0.00221592])
# Out:
# 0.9425246800000001
